# %%
import wikipydia
import re

# %%
def getLinksScore(pageName):
    #Download page structured by sections
    pageData = wikipydia.getPage(pageName)
    soup = pageData['full']

    #Clear table of contents if any
    for node in soup.findAll(id='toc'):
        node.decompose()

    #Clear top info table if any
    for node in soup.findAll(class_='ambox'):
        node.decompose()

    #Clear info box if any
    for node in soup.findAll(class_='infobox'):
        node.decompose()

    #Clear verticalbox if any
    for node in soup.findAll(class_='vertical-navbox'):
        node.decompose()


    #Get the wikilinks texts and build a set of target word
    #Avoid links with : that means special links for wikipedia
    #Clear parentheses in text cause it is not handled proper by text boundaries \b
    #targetWords = set([re.sub(r" \(.*\)", "", link.text.lower()) for link in soup.findAll('a') if link['href'][0:6] == '/wiki/' and not ':' in link['href']])
    targetLinks = set([(link['href'][6:], link.text.lower()) for link in soup.findAll('a') if link.has_attr('href') and link['href'][0:6] == '/wiki/' and not ':' in link['href'] and not '(disambiguation)' in link['href']])
    #check why the "for" word is appearing on python
    #test without removing parentheses


    #create and populate a hyper link dict
    hlDict = dict()
    for link, text in targetLinks:
        hlDict[text] = link

    sectionsSoup = pageData['sections']

    #Gen section texts based on article sections
    sectionTexts = []
    for section in sectionsSoup:
        sectionTexts.append(''.join([tag.text for tag in section]))

    presVects = []

    #Improve later with better importance algorithm and using vectors of meanings based on other articles links text
    importVector = getImportanceVector(sectionTexts)
    print(importVector)

    #MAYBE COUNT THE NUMBER OF TIMES A WORD APPEAR IN THE TEXT FOR ADITIONAL WEIGHT
    #NOW MUST THINK ABOUT THE INTERFACE AND WHERE WILL BE THE START POINT TO MEASURE THE HWO FAR

    for vec in getPresenceVector(sectionTexts, targetLinks).items():
        vecWeight = getVectorWeight(vec[1], importVector)
        presVects.append((vec[0],hlDict[vec[0]], vec[1][0], vecWeight))


    return presVects


def getPresenceVector(texts, targetLinks):
    wordDict = dict()

    #Iterate thru all target words
    for link in targetLinks:
        word = link[1] #Get link text
        wordDict[word] = []
        #Iterate thru all texts 
        for text in texts:
            #Match words inside its boundaries (non-alphanumeric chars)
            matches = re.findall('[^a-zA-Z0-9_]' + re.escape(word) + '[^a-zA-Z0-9_]', text, re.IGNORECASE)
            #matches = re.findall('\\b' + re.escape(word) + '\\b', text, re.IGNORECASE)
            #matches = re.findall('\\b' + word + '\\b', text, re.IGNORECASE)
            wordDict[word].append(len(matches))
            
    return wordDict

#For know just return a 2^n weight where n is the arraylength - index
def getImportanceVector(texts):
    textsLen = len(texts)
    return [2**(textsLen - n - 1) for n in range(textsLen)]

#Function to cross importance vector to generate an importance weight to the current presence vector
def getVectorWeight(targetVector, importanceVector):
    #raise an error if the target vector length is diferent from the importance vector length
    if len(targetVector) != len(importanceVector):
        raise "ERROR: Vectors length do not match. " + len(targetVector) + " " + len(importanceVector)

    valSum = 0
    for i, val in enumerate(targetVector):
        if val > 0:
            valSum += importanceVector[i]
    
    return valSum





#Test stuff
#if __name__ == "__main__":
    #import sys

    #def getVectVal(vect):
        #"""Function to return the sort value of the target vector"""
        #return vect[3]


    #presVects = getLinksScore(sys.argv[1])

    #presVects.sort(key=getVectVal, reverse=True)

    #for vect in presVects:
        #print vect[0].encode('utf-8'), vect[1], vect[2], vect[3]

# %%
links_score = getLinksScore("Node.js")

for link in sorted(links_score, key=lambda a: a[2], reverse=True):
    print(link)
# Out:
# [1]
# ('javascript', 'JavaScript', 42, 1)
# ('github', 'GitHub', 13, 1)
# ('microsoft', 'Microsoft', 11, 1)
# ('v8', 'V8_(JavaScript_engine)', 10, 1)
# ('visual studio', 'Microsoft_Visual_Studio', 10, 1)
# ('npm', 'Npm_(software)', 10, 1)
# ('typescript', 'TypeScript', 9, 1)
# ('google', 'Google', 8, 1)
# ('event loop', 'Event_loop', 8, 1)
# ('server-side', 'Server-side_JavaScript', 8, 1)
# ('c', 'C_(programming_language)', 8, 1)
# ('i/o', 'Input/output', 8, 1)
# ('frameworks', 'Software_framework', 7, 1)
# ('php', 'PHP', 6, 1)
# ('libuv', 'Libuv', 6, 1)
# ('callbacks', 'Callback_(computer_programming)', 6, 1)
# ('windows', 'Microsoft_Windows', 5, 1)
# ('joyent', 'Joyent', 5, 1)
# ('non-blocking', 'Asynchronous_I/O', 5, 1)
# ('linux', 'Linux', 5, 1)
# ('callback', 'Callback_(computer_programming)', 4, 1)
# ('client-side', 'Client-side_JavaScript', 4, 1)
# ('v8 javascript engine', 'V8_JavaScript_engine', 4, 1)
# ('isbn', 'International_Standard_Book_Number', 4, 1)
# ('visual studio code', 'Visual_Studio_Code', 4, 1)
# ('json', 'JSON', 4, 1)
# ('api', 'Application_programming_interface', 4, 1)
# ('webstorm', 'WebStorm', 4, 1)
# ('express.js', 'Express.js', 4, 1)
# ('web servers', 'Web_server', 4, 1)
# ('coffeescript', 'CoffeeScript', 4, 1)
# ('http', 'HTTP', 3, 1)
# ('sap', 'SAP_SE', 3, 1)
# ('linkedin', 'LinkedIn', 3, 1)
# ('nodeclipse', 'Nodeclipse', 3, 1)
# ('open-source', 'Open-source_software', 3, 1)
# ('john wiley & sons', 'John_Wiley_%26_Sons', 3, 1)
# ('unix', 'Unix', 3, 1)
# ('ides', 'Integrated_development_environment', 3, 1)
# ('cobol', 'COBOL', 3, 1)
# ('comparison', 'Comparison_of_JavaScript-based_source_code_editors', 3, 1)
# ('mongodb', 'MongoDB', 3, 1)
# ('nonstop', 'NonStop', 3, 1)
# ("o'reilly media", 'O%27Reilly_Media', 3, 1)
# ('package manager', 'Package_manager', 3, 1)
# ('ibm', 'IBM', 3, 1)
# ('fork', 'Fork_(software_development)', 3, 1)
# ('html', 'HTML', 3, 1)
# ('venturebeat', 'VentureBeat', 3, 1)
# ('commonjs', 'CommonJS', 3, 1)
# ('javascript library', 'JavaScript_library', 2, 1)
# ('technologies', 'Technology', 2, 1)
# ('dns', 'Domain_Name_System', 2, 1)
# ('linux foundation', 'Linux_Foundation', 2, 1)
# ('web applications', 'Web_application', 2, 1)
# ('yahoo!', 'Yahoo!', 2, 1)
# ('file system', 'File_system', 2, 1)
# ('nodejitsu', 'Nodejitsu', 2, 1)
# ('scalability', 'Scalability', 2, 1)
# ('koding', 'Koding', 2, 1)
# ('c++', 'C%2B%2B', 2, 1)
# ('meteor', 'Meteor_(web_framework)', 2, 1)
# ('paypal', 'PayPal', 2, 1)
# ('infoworld', 'Infoworld', 2, 1)
# ('os', 'Operating_system', 2, 1)
# ('atom', 'Atom_(text_editor)', 2, 1)
# ('groupon', 'Groupon', 2, 1)
# ('walmart', 'Walmart', 2, 1)
# ('event-driven programming', 'Event-driven_programming', 2, 1)
# ('ruby', 'Ruby_(programming_language)', 2, 1)
# ('single thread', 'Single_threading', 2, 1)
# ('netbeans', 'NetBeans', 2, 1)
# ('list of javascript libraries', 'List_of_JavaScript_libraries', 2, 1)
# ('node-red', 'Node-RED', 2, 1)
# ('julia', 'Julia_(programming_language)', 2, 1)
# ('sams publishing', 'SAMS_Publishing', 2, 1)
# ('brackets', 'Brackets_(text_editor)', 2, 1)
# ('asynchronous i/o', 'Asynchronous_I/O', 2, 1)
# ('lodash', 'Lodash', 2, 1)
# ('godaddy', 'GoDaddy', 2, 1)
# ('twit.tv', 'TWiT.tv', 2, 1)
# ('google v8', 'V8_(JavaScript_engine)', 2, 1)
# ('mean', 'MEAN_(software_bundle)', 2, 1)
# ('eclipse', 'Eclipse_(software)', 2, 1)
# ('tcp', 'Transmission_Control_Protocol', 2, 1)
# ('macos', 'MacOS', 2, 1)
# ('open governance', 'Open_governance', 2, 1)
# ('cloud9 ide', 'Cloud9_IDE', 2, 1)
# ('perl', 'Perl', 2, 1)
# ('dart', 'Dart_(programming_language)', 2, 1)
# ('python', 'Python_(programming_language)', 2, 1)
# ('unit testing', 'Unit_testing', 2, 1)
# ('threading', 'Thread_(computing)', 2, 1)
# ('codenvy', 'Codenvy', 1, 1)
# ('opa', 'Opa_(programming_language)', 1, 1)
# ('openshift', 'OpenShift', 1, 1)
# ('microsoft script debugger', 'Microsoft_Script_Debugger', 1, 1)
# ('list of javascript unit testing frameworks', 'List_of_unit_testing_frameworks#JavaScript', 1, 1)
# ('firebug', 'Firebug_(software)', 1, 1)
# ('angular', 'Angular_(application_platform)', 1, 1)
# ('haxe', 'Haxe', 1, 1)
# ('cisco systems', 'Cisco_Systems', 1, 1)
# ('can compile to javascript', 'Source-to-source_compiler', 1, 1)
# ('active server pages', 'Active_Server_Pages', 1, 1)
# ('lua', 'Lua_(programming_language)', 1, 1)
# ('jetbrains', 'JetBrains_MPS', 1, 1)
# ('microsoft script editor', 'Microsoft_Script_Editor', 1, 1)
# ('opera dragonfly', 'Opera_Dragonfly', 1, 1)
# ('jshint', 'JSHint', 1, 1)
# ('flickr', 'Flickr', 1, 1)
# ('web application', 'Web_application', 1, 1)
# ('client-side scripting', 'Client-side_scripting', 1, 1)
# ('transcompilers', 'Transcompiler', 1, 1)
# ('perlfor', 'Perl', 1, 1)
# ('freenode', 'Freenode', 1, 1)
# ('wayback machine', 'Wayback_Machine', 1, 1)
# ('couchdb', 'CouchDB', 1, 1)
# ('bsd license', 'BSD_license', 1, 1)
# ('perl object environment', 'Perl_Object_Environment', 1, 1)
# ('comparison of layout engines', 'Comparison_of_layout_engines_(ECMAScript)', 1, 1)
# ('venkman', 'Venkman', 1, 1)
# ('real-time web', 'Real-time_Web', 1, 1)
# ('visual studio express', 'Microsoft_Visual_Studio_Express', 1, 1)
# ('list of javascript engines', 'JavaScript_engine#JavaScript_engines', 1, 1)
# ('jasmine', 'Jasmine_(JavaScript_framework)', 1, 1)
# ('cpu cores', 'CPU_core', 1, 1)
# ('mvvm', 'Model_View_ViewModel', 1, 1)
# ('rakuten', 'Rakuten', 1, 1)
# ('microsoft .net', 'Microsoft_.NET', 1, 1)
# ('react.js', 'React.js', 1, 1)
# ('visual studio team services', 'Microsoft_Visual_Studio#Team_Services', 1, 1)
# ('package managers', 'Package_manager', 1, 1)
# ('microsoft typescript', 'Microsoft_TypeScript', 1, 1)
# ('java', 'Java_(programming_language)', 1, 1)
# ('comparison of javascript frameworks', 'Comparison_of_JavaScript_frameworks', 1, 1)
# ('dynamic web page', 'Dynamic_web_page', 1, 1)
# ('online javascript ide', 'Online_JavaScript_IDE', 1, 1)
# ('webassembly', 'WebAssembly', 1, 1)
# ('debuggers', 'Debugger', 1, 1)
# ('voxer', 'Voxer', 1, 1)
# ('vertical scaling', 'Vertical_scaling', 1, 1)
# ('komodo ide', 'Komodo_IDE', 1, 1)
# ('tuenti', 'Tuenti', 1, 1)
# ('brendan eich', 'Brendan_Eich', 1, 1)
# ('backbone.js', 'Backbone.js', 1, 1)
# ('microsoft windows', 'Microsoft_Windows', 1, 1)
# ('web development community', 'Web_developer', 1, 1)
# ('ember.js', 'Ember.js', 1, 1)
# ('jsdoc', 'JSDoc', 1, 1)
# ('machine code', 'Machine_code', 1, 1)
# ('vert.x', 'Vert.x', 1, 1)
# ('twisted', 'Twisted_(software)', 1, 1)
# ('google web toolkit', 'Google_Web_Toolkit', 1, 1)
# ('list of ecmascript engines', 'List_of_ECMAScript_engines', 1, 1)
# ('unobtrusive javascript', 'Unobtrusive_JavaScript', 1, 1)
# ('cascading style sheets', 'Cascading_Style_Sheets', 1, 1)
# ('event-driven architecture', 'Event-driven_architecture', 1, 1)
# ('dynamic html', 'Dynamic_HTML', 1, 1)
# ('john resig', 'John_Resig', 1, 1)
# ('real-time communication', 'Real-time_communication', 1, 1)
# ('non-blocking i/o', 'Non-blocking_I/O', 1, 1)
# ('scala', 'Scala_(programming_language)', 1, 1)
# ('code analysis', 'Static_code_analysis', 1, 1)
# ('jslint', 'JSLint', 1, 1)
# ('irc', 'IRC', 1, 1)
# ('the register', 'The_Register', 1, 1)
# ('codeanywhere', 'Codeanywhere', 1, 1)
# ('binary', 'Binary_file', 1, 1)
# ('digitalocean', 'DigitalOcean', 1, 1)
# ('atscript', 'AtScript', 1, 1)
# ('apress', 'Apress', 1, 1)
# ('douglas crockford', 'Douglas_Crockford', 1, 1)
# ('mean (software bundle)', 'MEAN_(software_bundle)', 1, 1)
# ('mvp', 'Model_View_Presenter', 1, 1)
# ('run-time environment', 'Runtime_system', 1, 1)
# ('underscore.js', 'Underscore.js', 1, 1)
# ('mvc', 'Model%E2%80%93view%E2%80%93controller', 1, 1)
# ('microsoft visual studio', 'Microsoft_Visual_Studio', 1, 1)
# ('progress bar', 'Progress_bar', 1, 1)
# ('socket.io', 'Socket.IO', 1, 1)
# ('nuget', 'NuGet', 1, 1)
# ('throughput', 'Throughput', 1, 1)
# ('posix', 'POSIX', 1, 1)
# ('es6', 'ECMAScript#ES6', 1, 1)
# ('reuse', 'Code_reuse', 1, 1)
# ('qunit', 'QUnit', 1, 1)
# ('clojurescript', 'ClojureScript', 1, 1)
# ('distributed development', 'Distributed_development', 1, 1)
# ('concurrency', 'Concurrent_computing', 1, 1)
# ('angularjs', 'AngularJS', 1, 1)
# ('ace', 'Ace_(editor)', 1, 1)
# ('jsgi', 'JSGI', 1, 1)
# ('gnd', 'Integrated_Authority_File', 1, 1)
# ('morfik', 'Morfik', 1, 1)
# ('block', 'Asynchronous_I/O', 1, 1)
# ('data streams', 'Stream_(computing)', 1, 1)
# ('cross-platform', 'Cross-platform', 1, 1)
# ('udp', 'User_Datagram_Protocol', 1, 1)
# ('codemirror', 'CodeMirror', 1, 1)
# ('application server', 'Application_server', 1, 1)
# ('observer pattern', 'Observer_pattern', 1, 1)
# ('heap allocation', 'Heap_allocation', 1, 1)
# ('server-side scripting', 'Server-side_scripting', 1, 1)
# ('google closure compiler', 'Google_Closure_Compiler', 1, 1)
# ('javascript syntax', 'JavaScript_syntax', 1, 1)
# ('ceylon', 'Ceylon_(programming_language)', 1, 1)
# ('google chrome', 'Google_Chrome', 1, 1)
# ('doc generators', 'Documentation_generator', 1, 1)
# ('cryptography', 'Cryptography', 1, 1)
# ('randal l. schwartz', 'Randal_L._Schwartz', 1, 1)
# ('browser games', 'Browser_game', 1, 1)
# ('eventmachine', 'EventMachine', 1, 1)
# ('postgres', 'PostgreSQL', 1, 1)
# ('groovy', 'Groovy_(programming_language)', 1, 1)
# ('rhino (javascript engine)', 'Rhino_(JavaScript_engine)', 1, 1)
# ('orion', 'List_of_Eclipse_projects#Top-level_sub-projects', 1, 1)
# ('web inspector', 'Web_Inspector', 1, 1)
# ('tls/ssl', 'Transport_Layer_Security', 1, 1)
# ('clojure', 'Clojure', 1, 1)
# ('emscripten', 'Emscripten', 1, 1)
# ('document object model', 'Document_Object_Model', 1, 1)
# ('mocha', 'Mocha_(JavaScript_framework)', 1, 1)
# ('linode', 'Linode', 1, 1)
# ('light table', 'Light_Table_(software)', 1, 1)
# ('netflix', 'Netflix', 1, 1)
# ('strongly typed', 'Strongly_typed', 1, 1)
# ('grunt', 'Grunt_(software)', 1, 1)
# ('context switching', 'Context_switch', 1, 1)
# ('filename extension', 'Filename_extension', 1, 1)
# ('ajax', 'Ajax_(programming)', 1, 1)
# ('wakanda', 'Wakanda_(software)', 1, 1)
